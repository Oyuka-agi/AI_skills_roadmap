# %% [markdown]
# <a href="https://colab.research.google.com/github/Oyuka-agi/AI_skills_roadmap/blob/main/pip_install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/requirements.txt'

# %%
import os
# List files in /content and /content/drive/MyDrive to find potential requirements files
print('Files in /content:')
# !ls /content

print('\nSearching for .txt or .cfg files in Drive:')
# !find /content/drive/MyDrive -maxdepth 1 -name "*requirements*" -o -name "*.txt"
# Out:
# Files in /content:
# drive  sample_data
#
# Searching for .txt or .cfg files in Drive:
